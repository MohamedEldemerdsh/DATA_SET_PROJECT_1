# %%
import pandas as pd
import  numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Titanic Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.duplicated().value_counts()
# Out:
# False    891
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
fig,axes=plt.subplots(1,2,figsize=(15,6))
sns.boxplot(x='Survived',y='Fare',data=df,ax=axes[0]).set(title='Fare')
sns.boxplot(x='Survived',y='Age',data=df,ax=axes[1]).set(title='Age')
# Out:
# [Text(0.5, 1.0, 'Age')]

# %%
sns.countplot(x='Sex',data=df)

# %%
sns.countplot(x='Sex',hue='Survived',data=df)
print(df['Sex'].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.barplot(x='Embarked',y='Pclass',data=df)

# %%
fig,axes=plt.subplots(2,2,figsize=(15,12))
sns.barplot(x='SibSp',y='Survived',data=df,ax=axes[0,0]).set(title='Survived Siblings')
sns.barplot(x='Parch',y='Survived',data=df,ax=axes[0,1]).set(title='Survived Parents')
sns.barplot(x='Pclass',y='Survived',data=df,ax=axes[1,0]).set(title='Survived Siblings')
sns.scatterplot(x='Survived',y='Age',hue='Sex',data=df,ax=axes[1,1])

# %%
fig,axes=plt.subplots(2,2,figsize=(15,12))
sns.countplot(x='SibSp',data=df,ax=axes[0,0]).set(title='Siblings')
print(df['SibSp'].value_counts())
sns.countplot(x='Parch',data=df,ax=axes[0,1]).set(title='No. of parents')
sns.countplot(x='Embarked',data=df,ax=axes[1,0]).set(title='Embarked Ports')
sns.countplot(x='Pclass',data=df,hue='Sex',ax=axes[1,1]).set(title='class distribution')
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# [Text(0.5, 1.0, 'class distribution')]

# %%
fig,axes=plt.subplots(2,2,figsize=(15,12))
sns.scatterplot(x='Fare',y='Age',data=df,ax=axes[0,0])
sns.scatterplot(x='Fare',y='Age',hue='Embarked',data=df,ax=axes[0,1])
sns.scatterplot(x='Fare',y='Age',hue='Sex',data=df,ax=axes[1,0])
sns.scatterplot(x='Pclass',y='Fare',hue='Sex',data=df,ax=axes[1,1])

# %%
Tickets=pd.DataFrame(df['Ticket'].value_counts())
Tickets[Tickets['Ticket']>2]
sns.countplot(x='Ticket',data=Tickets[Tickets['Ticket']>2])
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
df[df['Ticket']=='347082']
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 119          120         0       3
# 541          542         0       3
# 542          543         0       3
# 610          611         0       3
# 813          814         0       3
# 850          851         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 541               Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                  Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 850            Andersson, Master. Sigvard Harald Elias    male   4.0      4
#
#      Parch  Ticket    Fare Cabin Embarked
# ...

# %%
df[df['Ticket']=='CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked  has_cabin  cabin
# 159  NaN      8      2  CA. 2343  69.55   NaN        S          1    NaN
# 180  NaN      8      2  CA. 2343  69.55   NaN        S          1    NaN
# 201  NaN      8      2  CA. 2343  69.55   NaN        S          1    NaN
# ...

# %%
df['Cabin'].value_counts()
df[df['Cabin']=='G6']
# Out:
#      PassengerId  Survived  Pclass  \
# 10            11         1       3
# 205          206         0       3
# 251          252         0       3
# 394          395         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 205                         Strom, Miss. Telma Matilda  female   2.0      0
# 251         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
#
#      Parch   Ticket     Fare Cabin Embarked
# 10       1  PP 9549  16.7000    G6        S
# 205      1   347054  10.4625    G6        S
# 251      1   347054  10.4625    G6        S
# 394      2  PP 9549  16.7000    G6        S

# %%
df['has_cabin'] = np.where(df['Cabin'] ==pd.NA, 0,1)
df


df.loc[df['Cabin'] == np.nan,'cabin'] = 1

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age_missing']=df['Age'].fillna('missing_age')
X_DF=df[df['Age_missing']=='missing_age']['Survived']
X_DF.value_counts()
#####################################################
sns.countplot(x=X_DF,data=df,hue='Pclass',palette='viridis')

# %%
kids=df[df['Age']<18]['Survived']
#######################################
sns.countplot(x=kids,data=df,hue='Pclass',palette='viridis').set(title='Number of survived children under 18 years')
##Its obvious that most of dead children were 3rd class
# Out:
# [Text(0.5, 1.0, 'Number of survived children under 18 years')]

# %%
df['has_cabin']=df['Cabin'].fillna('0')
df[df['Age_missing']=='missing_age']['Cabin'].value_counts()
df[df['Age_missing']=='missing_age']['Pclass'].value_counts()
df['has_cabin'].value_counts()
###################################################################
df[(df['Age_missing']=='missing_age')&(df['Pclass']==1)]['Survived'].value_counts()
##people who dont have a cabin struggled to survive and most of them are dead
##the missing records doesnt have somthing to do with the Pclass or the fare
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 55            56         1       1
# 64            65         0       1
# 166          167         1       1
# 168          169         0       1
# 185          186         0       1
# 256          257         1       1
# 270          271         0       1
# 284          285         0       1
# 295          296         0       1
# 298          299         1       1
# 306          307         1       1
# 334          335         1       1
# 351          352         0       1
# 375          376         1       1
# 457          458         1       1
# 475          476         0       1
# 507          508         1       1
# 527          528         0       1
# 557          558         0       1
# 602          603         0       1
# 633          634         0       1
# 669          670         1       1
# 711          712         0       1
# 740          741         1       1
# ...
